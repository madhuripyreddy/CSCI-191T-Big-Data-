# %%
import numpy as np 
import pandas as pd

# %%
import pandas as pd 
df = pd.read_csv("./movies_metadata.csv");
df.head()
# Out:
# C:\Users\reddy\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    adult                              belongs_to_collection    budget  \
# 0  FALSE  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  FALSE                                                NaN  65000000
# 2  FALSE  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  FALSE                                                NaN  16000000
# 4  FALSE  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...

# %%
df['budget']
# Out:
# 0        30000000
# 1        65000000
# 2               0
# 3        16000000
# 4               0
#            ...
# 45461           0
# 45462           0
# 45463           0
# 45464           0
# 45465           0
# Name: budget, Length: 45466, dtype: object

# %%
notlist = []
removeList = []
for index,EveryRow in df.iterrows():
    try:
        value = int(EveryRow['budget'])
        if value != 0:
            removeList.append(index)
    except ValueError or TypeError:
        notlist.append(index)
        removeList.append(index)
print(notlist)
print(removeList)
# Out:
# [19730, 29503, 35587]
# ...

# %%
new=df.drop(notlist,axis=0)
final=df.drop(removeList,axis=0)
new['budget']=new.budget.astype(float)
final['budget'] = final.budget.astype(float)
print(new['budget'])
print(final['budget'])
# Out:
# 0        30000000.0
# 1        65000000.0
# 2               0.0
# 3        16000000.0
# 4               0.0
#             ...
# 45461           0.0
# 45462           0.0
# 45463           0.0
# 45464           0.0
# 45465           0.0
# Name: budget, Length: 45463, dtype: float64
# 2        0.0
# 4        0.0
# 7        0.0
# 11       0.0
# 12       0.0
#         ...
# 45461    0.0
# 45462    0.0
# 45463    0.0
# 45464    0.0
# 45465    0.0
# Name: budget, Length: 36573, dtype: float64

# %%
new['budget'].mean()
# Out:
# 4224578.813474693

# %%
new['budget'].median()
# Out:
# 0.0

# %%
new['budget'].std()
# Out:
# 17424132.63433535

# %%
new['budget'].var()
# Out:
# 303600398058910.2

# %%
new['budget'].describe()
# Out:
# count    4.546300e+04
# mean     4.224579e+06
# std      1.742413e+07
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      3.800000e+08
# Name: budget, dtype: float64
