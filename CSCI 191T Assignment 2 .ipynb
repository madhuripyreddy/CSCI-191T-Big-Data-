# %%
import pandas as pd
data=pd.read_csv("./diabetes.tab.csv");
data.head(20)
# Out:
#     AGE  SEX   BMI     BP   S1     S2    S3    S4      S5  S6    Y
# 0    59    2  32.1  101.0  157   93.2  38.0  4.00  4.8598  87  151
# 1    48    1  21.6   87.0  183  103.2  70.0  3.00  3.8918  69   75
# 2    72    2  30.5   93.0  156   93.6  41.0  4.00  4.6728  85  141
# 3    24    1  25.3   84.0  198  131.4  40.0  5.00  4.8903  89  206
# 4    50    1  23.0  101.0  192  125.4  52.0  4.00  4.2905  80  135
# 5    23    1  22.6   89.0  139   64.8  61.0  2.00  4.1897  68   97
# 6    36    2  22.0   90.0  160   99.6  50.0  3.00  3.9512  82  138
# 7    66    2  26.2  114.0  255  185.0  56.0  4.55  4.2485  92   63
# 8    60    2  32.1   83.0  179  119.4  42.0  4.00  4.4773  94  110
# 9    29    1  30.0   85.0  180   93.4  43.0  4.00  5.3845  88  310
# 10   22    1  18.6   97.0  114   57.6  46.0  2.00  3.9512  83  101
# 11   56    2  28.0   85.0  184  144.8  32.0  6.00  3.5835  77   69
# 12   53    1  23.7   92.0  186  109.2  62.0  3.00  4.3041  81  179
# 13   50    2  26.2   97.0  186  105.4  49.0  4.00  5.0626  88  185
# 14   61    1  24.0   91.0  202  115.4  72.0  3.00  4.2905  73  118
# 15   34    2  24.7  118.0  254  184.2  39.0  7.00  5.0370  81  171
# 16   47    1  30.3  109.0  207  100.2  70.0  3.00  5.2149  98  166
# 17   68    2  27.5  111.0  214  147.0  39.0  5.00  4.9416  91  144
# 18   38    1  25.4   84.0  162  103.0  42.0  4.00  4.4427  87   97
# 19   41    1  24.7   83.0  187  108.2  60.0  3.00  4.5433  78  168

# %%
data.corr()
# Out:
#           AGE       SEX       BMI        BP        S1        S2        S3  \
# AGE  1.000000  0.173737  0.185085  0.335428  0.260061  0.219243 -0.075181
# SEX  0.173737  1.000000  0.088161  0.241010  0.035277  0.142637 -0.379090
# BMI  0.185085  0.088161  1.000000  0.395411  0.249777  0.261170 -0.366811
# BP   0.335428  0.241010  0.395411  1.000000  0.242464  0.185548 -0.178762
# S1   0.260061  0.035277  0.249777  0.242464  1.000000  0.896663  0.051519
# S2   0.219243  0.142637  0.261170  0.185548  0.896663  1.000000 -0.196455
# S3  -0.075181 -0.379090 -0.366811 -0.178762  0.051519 -0.196455  1.000000
# S4   0.203841  0.332115  0.413807  0.257650  0.542207  0.659817 -0.738493
# S5   0.270774  0.149916  0.446157  0.393480  0.515503  0.318357 -0.398577
# S6   0.301731  0.208133  0.388680  0.390430  0.325717  0.290600 -0.273697
# Y    0.187889  0.043062  0.586450  0.441482  0.212022  0.174054 -0.394789
#
#            S4        S5        S6         Y
# AGE  0.203841  0.270774  0.301731  0.187889
# SEX  0.332115  0.149916  0.208133  0.043062
# BMI  0.413807  0.446157  0.388680  0.586450
# BP   0.257650  0.393480  0.390430  0.441482
# S1   0.542207  0.515503  0.325717  0.212022
# S2   0.659817  0.318357  0.290600  0.174054
# S3  -0.738493 -0.398577 -0.273697 -0.394789
# S4   1.000000  0.617859  0.417212  0.430453
# S5   0.617859  1.000000  0.464669  0.565883
# S6   0.417212  0.464669  1.000000  0.382483
# Y    0.430453  0.565883  0.382483  1.000000

# %%
data['Y'].mean()
# Out:
# 152.13348416289594

# %%
data['Y'].median()
# Out:
# 140.5

# %%
data['Y'].mode()
# Out:
# 0     72
# 1    200
# dtype: int64

# %%
data['Y'].std()
# Out:
# 77.09300453299109

# %%
data['Y'].var()
# Out:
# 5943.331347923785

# %%
data['Y'].describe()
# Out:
# count    442.000000
# mean     152.133484
# std       77.093005
# min       25.000000
# 25%       87.000000
# 50%      140.500000
# 75%      211.500000
# max      346.000000
# Name: Y, dtype: float64

# %%
data['AGE'].mean()
# Out:
# 48.51809954751131

# %%
data['AGE'].median()
# Out:
# 50.0

# %%
data['AGE'].mode()
# Out:
# 0    53
# dtype: int64

# %%
data['AGE'].std()
# Out:
# 13.109027822041087

# %%
data['AGE'].var()
# Out:
# 171.84661043904728

# %%
data['AGE'].describe()
# Out:
# count    442.000000
# mean      48.518100
# std       13.109028
# min       19.000000
# 25%       38.250000
# 50%       50.000000
# 75%       59.000000
# max       79.000000
# Name: AGE, dtype: float64

# %%
data['BMI'].mean()
# Out:
# 26.37579185520364

# %%
data['BMI'].median()
# Out:
# 25.7

# %%
data['BMI'].mode()
# Out:
# 0    23.5
# 1    24.1
# dtype: float64

# %%
data['BMI'].describe()
# Out:
# count    442.000000
# mean      26.375792
# std        4.418122
# min       18.000000
# 25%       23.200000
# 50%       25.700000
# 75%       29.275000
# max       42.200000
# Name: BMI, dtype: float64

# %%
data['BP'].mean()
# Out:
# 94.64701357466065

# %%
data['BP'].median()
# Out:
# 93.0

# %%
data['BP'].mode()
# Out:
# 0    83.0
# 1    93.0
# dtype: float64

# %%
data['BP'].std()
# Out:
# 13.831283419783

# %%
data['BP'].var()
# Out:
# 191.30440103836415

# %%
data['BP'].describe()
# Out:
# count    442.000000
# mean      94.647014
# std       13.831283
# min       62.000000
# 25%       84.000000
# 50%       93.000000
# 75%      105.000000
# max      133.000000
# Name: BP, dtype: float64

# %%
import pandas as pd
data=pd.read_csv("./diabetes.tab.csv");
data.head(20)
# Out:
#     AGE  SEX   BMI     BP   S1     S2    S3    S4      S5  S6    Y
# 0    59    2  32.1  101.0  157   93.2  38.0  4.00  4.8598  87  151
# 1    48    1  21.6   87.0  183  103.2  70.0  3.00  3.8918  69   75
# 2    72    2  30.5   93.0  156   93.6  41.0  4.00  4.6728  85  141
# 3    24    1  25.3   84.0  198  131.4  40.0  5.00  4.8903  89  206
# 4    50    1  23.0  101.0  192  125.4  52.0  4.00  4.2905  80  135
# 5    23    1  22.6   89.0  139   64.8  61.0  2.00  4.1897  68   97
# 6    36    2  22.0   90.0  160   99.6  50.0  3.00  3.9512  82  138
# 7    66    2  26.2  114.0  255  185.0  56.0  4.55  4.2485  92   63
# 8    60    2  32.1   83.0  179  119.4  42.0  4.00  4.4773  94  110
# 9    29    1  30.0   85.0  180   93.4  43.0  4.00  5.3845  88  310
# 10   22    1  18.6   97.0  114   57.6  46.0  2.00  3.9512  83  101
# 11   56    2  28.0   85.0  184  144.8  32.0  6.00  3.5835  77   69
# 12   53    1  23.7   92.0  186  109.2  62.0  3.00  4.3041  81  179
# 13   50    2  26.2   97.0  186  105.4  49.0  4.00  5.0626  88  185
# 14   61    1  24.0   91.0  202  115.4  72.0  3.00  4.2905  73  118
# 15   34    2  24.7  118.0  254  184.2  39.0  7.00  5.0370  81  171
# 16   47    1  30.3  109.0  207  100.2  70.0  3.00  5.2149  98  166
# 17   68    2  27.5  111.0  214  147.0  39.0  5.00  4.9416  91  144
# 18   38    1  25.4   84.0  162  103.0  42.0  4.00  4.4427  87   97
# 19   41    1  24.7   83.0  187  108.2  60.0  3.00  4.5433  78  168

# %%
data = data.drop('SEX',axis=1)
data.head()
# Out:
#    AGE   BMI     BP   S1     S2    S3   S4      S5  S6    Y
# 0   59  32.1  101.0  157   93.2  38.0  4.0  4.8598  87  151
# 1   48  21.6   87.0  183  103.2  70.0  3.0  3.8918  69   75
# 2   72  30.5   93.0  156   93.6  41.0  4.0  4.6728  85  141
# 3   24  25.3   84.0  198  131.4  40.0  5.0  4.8903  89  206
# 4   50  23.0  101.0  192  125.4  52.0  4.0  4.2905  80  135

# %%
data = data.drop('BP',axis=1)
data.head()
# Out:
#    AGE   BMI   S1     S2    S3   S4      S5  S6    Y
# 0   59  32.1  157   93.2  38.0  4.0  4.8598  87  151
# 1   48  21.6  183  103.2  70.0  3.0  3.8918  69   75
# 2   72  30.5  156   93.6  41.0  4.0  4.6728  85  141
# 3   24  25.3  198  131.4  40.0  5.0  4.8903  89  206
# 4   50  23.0  192  125.4  52.0  4.0  4.2905  80  135

# %%
data = data.drop('S1',axis=1)
data.head()
# Out:
#    AGE   BMI     S2    S3   S4      S5  S6    Y
# 0   59  32.1   93.2  38.0  4.0  4.8598  87  151
# 1   48  21.6  103.2  70.0  3.0  3.8918  69   75
# 2   72  30.5   93.6  41.0  4.0  4.6728  85  141
# 3   24  25.3  131.4  40.0  5.0  4.8903  89  206
# 4   50  23.0  125.4  52.0  4.0  4.2905  80  135

# %%
data = data.drop('S2',axis=1)
data.head()
# Out:
#    AGE   BMI    S3   S4      S5  S6    Y
# 0   59  32.1  38.0  4.0  4.8598  87  151
# 1   48  21.6  70.0  3.0  3.8918  69   75
# 2   72  30.5  41.0  4.0  4.6728  85  141
# 3   24  25.3  40.0  5.0  4.8903  89  206
# 4   50  23.0  52.0  4.0  4.2905  80  135

# %%
data = data.drop('S3',axis=1)
data.head()
# Out:
#    AGE   BMI   S4      S5  S6    Y
# 0   59  32.1  4.0  4.8598  87  151
# 1   48  21.6  3.0  3.8918  69   75
# 2   72  30.5  4.0  4.6728  85  141
# 3   24  25.3  5.0  4.8903  89  206
# 4   50  23.0  4.0  4.2905  80  135

# %%
data = data.drop('S4',axis=1)
data.head()
# Out:
#    AGE   BMI      S5  S6    Y
# 0   59  32.1  4.8598  87  151
# 1   48  21.6  3.8918  69   75
# 2   72  30.5  4.6728  85  141
# 3   24  25.3  4.8903  89  206
# 4   50  23.0  4.2905  80  135

# %%
data = data.drop('S5',axis=1)
data.head()
# Out:
#    AGE   BMI  S6    Y
# 0   59  32.1  87  151
# 1   48  21.6  69   75
# 2   72  30.5  85  141
# 3   24  25.3  89  206
# 4   50  23.0  80  135

# %%
data = data.drop('S6',axis=1)
data.head()
# Out:
#    AGE   BMI    Y
# 0   59  32.1  151
# 1   48  21.6   75
# 2   72  30.5  141
# 3   24  25.3  206
# 4   50  23.0  135

# %%
data = data.drop('Y',axis=1)
data.head()
# Out:
#    AGE   BMI
# 0   59  32.1
# 1   48  21.6
# 2   72  30.5
# 3   24  25.3
# 4   50  23.0

# %%
y=data['BMI']
x=data.AGE

# %matplotlib inline

from matplotlib import pyplot as plt

# Increase the size of the plot
plt.figure(figsize=(20,10))

# Create a scatter plot: Number of stores in the District vs. Annual Net Sales
plt.plot(x,y, 'o', markersize = 15)

# Add axis labels and increase the font size
plt.ylabel('BMI', fontsize = 30)
plt.xlabel('AGE', fontsize = 30)

# Increase the font size on the ticks on the x and y axis
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)

# Display the scatter plot
plt.show()

# %%
import pandas as pd 
import numpy as np 
import statistics as st
m, b = np.polyfit(x,y,1) 
print ('The slope of line is {:.2f}.'.format(m))
print ('The y-intercept is {:.2f}.'.format(b))
print ('The best fit simple linear regression line is {:.2f}x + {:.2f}.'.format(m,b))
# Out:
# The slope of line is 0.06.
# The y-intercept is 23.35.
# The best fit simple linear regression line is 0.06x + 23.35.

# %%
# %matplotlib inline

# Code Cell 9
# y coordinate for centroid
y_mean = y.mean()    
# x coordinate for centroid
x_mean = x.mean()
print ('The centroid for this dataset is x = {:.2f} and y = {:.2f}.'.format(x_mean, y_mean))
# Out:
# The centroid for this dataset is x = 48.52 and y = 26.38.

# %%
# Code Cell 10
# Create the plot inline
# %matplotlib inline
from matplotlib import pyplot as plt
# Enlarge the plot size
plt.figure(figsize=(20,10))

# Plot the scatter plot of the data set
plt.plot(x,y, 'o', markersize = 14, label = "BMI") 

# Plot the centroid point
plt.plot(x_mean,y_mean, '*', markersize = 30, color = "r") 

# Plot the linear regression line
plt.plot(x, m*x + b, '-', label = 'Simple Linear Regression Line', linewidth = 4)

# Create the x and y axis labels
plt.ylabel('BMI', fontsize = 30)
plt.xlabel('AGE', fontsize = 30)

# Enlarge x and y tick marks
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)

# Point out the centroid point in the plot
plt.annotate('Centroid', xy=(x_mean-0.1, y_mean-5), xytext=(x_mean-3, y_mean-20), arrowprops=dict(facecolor='black', shrink=0.05), fontsize = 30)

# Create legend
plt.legend(loc = 'upper right', fontsize = 20)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
data=pd.read_csv("./Downloads/diabetes.tab.csv");
data.head(20)
# Out:
#     AGE  SEX   BMI     BP   S1     S2    S3    S4      S5  S6    Y
# 0    59    2  32.1  101.0  157   93.2  38.0  4.00  4.8598  87  151
# 1    48    1  21.6   87.0  183  103.2  70.0  3.00  3.8918  69   75
# 2    72    2  30.5   93.0  156   93.6  41.0  4.00  4.6728  85  141
# 3    24    1  25.3   84.0  198  131.4  40.0  5.00  4.8903  89  206
# 4    50    1  23.0  101.0  192  125.4  52.0  4.00  4.2905  80  135
# 5    23    1  22.6   89.0  139   64.8  61.0  2.00  4.1897  68   97
# 6    36    2  22.0   90.0  160   99.6  50.0  3.00  3.9512  82  138
# 7    66    2  26.2  114.0  255  185.0  56.0  4.55  4.2485  92   63
# 8    60    2  32.1   83.0  179  119.4  42.0  4.00  4.4773  94  110
# 9    29    1  30.0   85.0  180   93.4  43.0  4.00  5.3845  88  310
# 10   22    1  18.6   97.0  114   57.6  46.0  2.00  3.9512  83  101
# 11   56    2  28.0   85.0  184  144.8  32.0  6.00  3.5835  77   69
# 12   53    1  23.7   92.0  186  109.2  62.0  3.00  4.3041  81  179
# 13   50    2  26.2   97.0  186  105.4  49.0  4.00  5.0626  88  185
# 14   61    1  24.0   91.0  202  115.4  72.0  3.00  4.2905  73  118
# 15   34    2  24.7  118.0  254  184.2  39.0  7.00  5.0370  81  171
# 16   47    1  30.3  109.0  207  100.2  70.0  3.00  5.2149  98  166
# 17   68    2  27.5  111.0  214  147.0  39.0  5.00  4.9416  91  144
# 18   38    1  25.4   84.0  162  103.0  42.0  4.00  4.4427  87   97
# 19   41    1  24.7   83.0  187  108.2  60.0  3.00  4.5433  78  168

# %%
data = data.drop('AGE',axis=1)
data.head()
# Out:
#    SEX   BMI     BP   S1     S2    S3   S4      S5  S6    Y
# 0    2  32.1  101.0  157   93.2  38.0  4.0  4.8598  87  151
# 1    1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69   75
# 2    2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85  141
# 3    1  25.3   84.0  198  131.4  40.0  5.0  4.8903  89  206
# 4    1  23.0  101.0  192  125.4  52.0  4.0  4.2905  80  135

# %%
data = data.drop('SEX',axis=1)
data.head()
# Out:
#     BMI     BP   S1     S2    S3   S4      S5  S6    Y
# 0  32.1  101.0  157   93.2  38.0  4.0  4.8598  87  151
# 1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69   75
# 2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85  141
# 3  25.3   84.0  198  131.4  40.0  5.0  4.8903  89  206
# 4  23.0  101.0  192  125.4  52.0  4.0  4.2905  80  135

# %%
data = data.drop('S1',axis=1)
data.head()
# Out:
#     BMI     BP     S2    S3   S4      S5  S6    Y
# 0  32.1  101.0   93.2  38.0  4.0  4.8598  87  151
# 1  21.6   87.0  103.2  70.0  3.0  3.8918  69   75
# 2  30.5   93.0   93.6  41.0  4.0  4.6728  85  141
# 3  25.3   84.0  131.4  40.0  5.0  4.8903  89  206
# 4  23.0  101.0  125.4  52.0  4.0  4.2905  80  135

# %%
data = data.drop('S2',axis=1)
data.head()
# Out:
#     BMI     BP    S3   S4      S5  S6    Y
# 0  32.1  101.0  38.0  4.0  4.8598  87  151
# 1  21.6   87.0  70.0  3.0  3.8918  69   75
# 2  30.5   93.0  41.0  4.0  4.6728  85  141
# 3  25.3   84.0  40.0  5.0  4.8903  89  206
# 4  23.0  101.0  52.0  4.0  4.2905  80  135

# %%
data = data.drop('S3',axis=1)
data.head()
# Out:
#     BMI     BP   S4      S5  S6    Y
# 0  32.1  101.0  4.0  4.8598  87  151
# 1  21.6   87.0  3.0  3.8918  69   75
# 2  30.5   93.0  4.0  4.6728  85  141
# 3  25.3   84.0  5.0  4.8903  89  206
# 4  23.0  101.0  4.0  4.2905  80  135

# %%
data = data.drop('S4',axis=1)
data.head()
# Out:
#     BMI     BP      S5  S6    Y
# 0  32.1  101.0  4.8598  87  151
# 1  21.6   87.0  3.8918  69   75
# 2  30.5   93.0  4.6728  85  141
# 3  25.3   84.0  4.8903  89  206
# 4  23.0  101.0  4.2905  80  135

# %%
data = data.drop('S5',axis=1)
data.head()
# Out:
#     BMI     BP  S6    Y
# 0  32.1  101.0  87  151
# 1  21.6   87.0  69   75
# 2  30.5   93.0  85  141
# 3  25.3   84.0  89  206
# 4  23.0  101.0  80  135

# %%
data = data.drop('S6',axis=1)
data.head()
# Out:
#     BMI     BP    Y
# 0  32.1  101.0  151
# 1  21.6   87.0   75
# 2  30.5   93.0  141
# 3  25.3   84.0  206
# 4  23.0  101.0  135

# %%
y=data['Y']
x=data.BMI
# %matplotlib inline

from matplotlib import pyplot as plt

# Increase the size of the plot
plt.figure(figsize=(20,10))

# Create a scatter plot: Number of stores in the District vs. Annual Net Sales
plt.plot(x,y, 'o', markersize = 15)

# Add axis labels and increase the font size
plt.ylabel('Y', fontsize = 30)
plt.xlabel('BMI', fontsize = 30)

# Increase the font size on the ticks on the x and y axis
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)

# Display the scatter plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
m, b = np.polyfit(x,y,1) 
print ('The slope of line is {:.2f}.'.format(m))
print ('The y-intercept is {:.2f}.'.format(b))
print ('The best fit simple linear regression line is {:.2f}x + {:.2f}.'.format(m,b))
# Out:
# The slope of line is 10.23.
# The y-intercept is -117.77.
# The best fit simple linear regression line is 10.23x + -117.77.

# %%
# %matplotlib inline

# Code Cell 9
# y coordinate for centroid
y_mean = y.mean()    
# x coordinate for centroid
x_mean = x.mean()
print ('The centroid for this dataset is x = {:.2f} and y = {:.2f}.'.format(x_mean, y_mean))
# Out:
# The centroid for this dataset is x = 26.38 and y = 152.13.

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# Enlarge the plot size
plt.figure(figsize=(20,10))

# Plot the scatter plot of the data set
plt.plot(x,y, 'o', markersize = 14, label = "Y") 

# Plot the centroid point
plt.plot(x_mean,y_mean, '*', markersize = 30, color = "r") 

# Plot the linear regression line
plt.plot(x, m*x + b, '-', label = 'Simple Linear Regression Line', linewidth = 4)

# Create the x and y axis labels
plt.ylabel('Y', fontsize = 30)
plt.xlabel('BMI', fontsize = 30)

# Enlarge x and y tick marks
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)

# Point out the centroid point in the plot
plt.annotate('Centroid', xy=(x_mean-0.1, y_mean-5), xytext=(x_mean-3, y_mean-20), arrowprops=dict(facecolor='black', shrink=0.05), fontsize = 30)

# Create legend
plt.legend(loc = 'upper right', fontsize = 20)

# %%
bpx = data.iloc[:,0:1].values

bpy = data.iloc[:,1:2].values

from sklearn.linear_model import LinearRegression

lin = LinearRegression()
lin.fit(bpx,bpy)

# Fitting Polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
 
poly = PolynomialFeatures(degree = 4)
X_poly = poly.fit_transform(bpx)
 
poly.fit(X_poly, )
lin2 = LinearRegression()
lin2.fit(X_poly, bpy)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Visualising the Linear Regression results
#%matplotlib inline
#from matplotlib import pyplot as plt
plt.scatter(x, y, color = 'blue')

plt.plot(x, lin.predict(x), color = 'red')
plt.title('Linear Regression')
plt.xlabel('BMI ')
plt.ylabel('Progress')
 
plt.show()

# %%
m=lin.predict(x)
y= data.iloc[:,1:2].values
from sklearn.metrics import mean_squared_error
mean_squared_error(m,y)
# Out:
# 12402.850097672064

# %%
bpx = data.iloc[:,1:2].values

bpy = data.iloc[:,2:3].values

from sklearn.linear_model import LinearRegression

lin = LinearRegression()
lin.fit(bpx,bpy)

# Fitting Polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
 
poly = PolynomialFeatures(degree = 4)
X_poly = poly.fit_transform(bpx)
 
poly.fit(X_poly, )
lin2 = LinearRegression()
lin2.fit(X_poly, bpy)
plt.scatter(bpX, progress, color = 'blue')
 
plt.plot(bpX, lin.predict(bpX), color = 'red')
plt.title('Linear Regression')
plt.xlabel('Blood Pressure')
plt.ylabel('Progression')
 
plt.show()

# %%
m=lin.predict(bpx)
from sklearn.metrics import mean_squared_error
mean_squared_error(m,y)
# Out:
# 3711.967214825889
